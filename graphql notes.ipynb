# %% [markdown]
# #fetch all the events
# query {
#   fetchEvents {
#     id
#     name
#     description
#     date
#     capacity
#   }
# }
#
# #Fetch user details
# query {
#   fetchUserDetails(userId: 1) {
#     id
#     name
#     email
#     role
#   }
# }
#
# #mutuation login
# mutation {
#   login(email: "vimal098@gmail.com", password: "122345678") {
#     token
#     user {
#       id
#       name
#       email
#       role
#     }
#   }
# }
#
# #add event
# mutation {
#   addEvent(name: "sport Conference 2024", description: "A IT event for corporate people", date: "2024-05-01", capacity: 1000) {
#     id
#     name
#     description
#     date
#     capacity
#   }
# }
#
# #delete Event
#
# mutation {
#   deleteEvent(eventId:13) {
#     id
#     name
#     description
#     date
#     capacity
#   }
# }
#
# #update the event capacity
# mutation {
#   updateEventCapacity(eventId: 10, capacity: 10000) {
#     id
#     name
#     description
#     date
#     capacity
#   }
# }
#
#
# #add a user
# mutation {
#   addUser(name: "riya", email: "riya09@gmail.com", password: "012456789", role: "User") {
#     id
#     name
#     email
#     role
#   }
# }
#
# #register a event
# mutation {
#   registerForEvent(eventId: 4, userId: 6) {
#     id
#     name
#     description
#     date
#     capacity
#   }
# }
